# %% [markdown]
# # This file for developing the CNN-LSTM Bean leaf disease classifier
# by using original, augmented datasets

# %% [markdown]
# ### Check Environment

# %%
# !cat /proc/cpuinfo | grep "model name" | head -1

# %%
# !cat /etc/*release

# %%
# !nvidia-smi

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
assert tf.__version__.startswith('2')
#import keras
import random
import itertools
import os
import matplotlib.pyplot as plt
from google.colab import files, drive
#from re import X

from sklearn.metrics import matthews_corrcoef, confusion_matrix, f1_score

# %matplotlib inline

# %%
print(tf.version.VERSION)
# Out:
# 2.17.0

# %% [markdown]
# #### Set random seeds

# %%
# Random seeds
random.seed(111)
np.random.seed(111)
tf.random.set_seed(111)

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
WIDTH = 300 # image width
HEIGHT = 300  #image height
CHANNELS = 3
SHAPE = (WIDTH, HEIGHT, CHANNELS)
IMAGE_SIZE = [WIDTH, HEIGHT]
TOTAL_INPUTS = WIDTH * HEIGHT * CHANNELS
LABELS = ['Angular Leaf Spot', 'Bean Rust', 'Healthy']

# total number of training samples
TRAIN = 905
AUG_SAMPLES = 2715
MODEL = 'CNN-LSTM: '

# Total samples of images
SAMPLES = 1295
CLASSES = 3
#  Parameter values
BATCH = [16, 32, 64]
LEARNING_RATE = [1e-4, 1e-3, 1e-2]
#NEURONS = [CLASSES, 16, 32, 64, 128]

# Original data file names
X_TRAIN = 'x_train_original.npy'  #905
X_VAL = 'x_val.npy'  # 195
X_TEST = 'x_test.npy'  #195
Y_TRAIN = 'y_train_original.npy'  #905
Y_VAL = 'y_val.npy'  #195
Y_TEST = 'y_test.npy'  #195

# Transformed data file names
X_TRAIN_ROTATE = 'x_train_rotate.npy'
Y_TRAIN_ROTATE = 'y_train_rotate.npy'
X_TRAIN_FLIP = 'x_train_flip.npy'
Y_TRAIN_FLIP = 'y_train_flip.npy'
X_TRAIN_CROP = 'x_train_crop.npy'
Y_TRAIN_CROP = 'y_train_crop.npy'
X_TRAIN_BRIGHT = 'x_train_bright.npy'
Y_TRAIN_BRIGHT = 'y_train_bright.npy'
X_TRAIN_COMBINE = 'x_train_combine.npy'
Y_TRAIN_COMBINE = 'y_train_combine.npy'

# %% [markdown]
# # Load data
# from files
# ####Note: variables x_train and y_train are reused for all training sets, validation and test sets are the same for all training

# %%
### Original dataset
#x_train = np.load('/content/drive/MyDrive/Colab Notebooks/'+ X_TRAIN)
#y_train = np.load('/content/drive/MyDrive/Colab Notebooks/'+ Y_TRAIN)

x_val = np.load('/content/drive/MyDrive/Colab Notebooks/'+ X_VAL)
y_val = np.load('/content/drive/MyDrive/Colab Notebooks/'+ Y_VAL)

x_test = np.load('/content/drive/MyDrive/Colab Notebooks/'+ X_TEST)
y_test = np.load('/content/drive/MyDrive/Colab Notebooks/'+ Y_TEST)


# !!!Augmented training data, Must share the x_train and the y_train variables.
# # ROTATE
#x_train = np.load('/content/drive/MyDrive/Colab Notebooks/'+ X_TRAIN_ROTATE)
#y_train = np.load('/content/drive/MyDrive/Colab Notebooks/'+ Y_TRAIN_ROTATE)
# # FLIP
x_train = np.load('/content/drive/MyDrive/Colab Notebooks/'+ X_TRAIN_FLIP)
y_train = np.load('/content/drive/MyDrive/Colab Notebooks/'+ Y_TRAIN_FLIP)
# # CROP
#x_train = np.load('/content/drive/MyDrive/Colab Notebooks/'+ X_TRAIN_CROP)
#y_train = np.load('/content/drive/MyDrive/Colab Notebooks/'+ Y_TRAIN_CROP)
# # COMBINATION
#x_train = np.load('/content/drive/MyDrive/Colab Notebooks/'+ X_TRAIN_COMBINE)
#y_train = np.load('/content/drive/MyDrive/Colab Notebooks/'+ Y_TRAIN_COMBINE)
# # BRIGHTNESS
#x_train = np.load('/content/drive/MyDrive/Colab Notebooks/'+ X_TRAIN_BRIGHT)
#y_train = np.load('/content/drive/MyDrive/Colab Notebooks/'+ Y_TRAIN_BRIGHT)

# %%
# Reshape feature array into 3-dim
x_train = np.reshape(x_train, (-1, HEIGHT, WIDTH, CHANNELS))
x_val = np.reshape(x_val, (-1, HEIGHT, WIDTH, CHANNELS))
x_test = np.reshape(x_test, (-1, HEIGHT, WIDTH, CHANNELS))

# %% [markdown]
# ## Normalise data

# %%
x_train = x_train/255.0
x_test = x_test/255.0
x_val = x_val/255.0

# %%
#  Check the dimension
print(f'x_train= {x_train.shape}, x_val = {x_val.shape}, x_test = {x_test.shape}')
# Out:
# x_train= (2715, 300, 300, 3), x_val = (195, 300, 300, 3), x_test = (195, 300, 300, 3)

# %% [markdown]
# # Core functions

# %%
# show sample images
def sample_random_images(nums):
  fig = plt.figure(figsize=(10, 10))
  for i in range(len(nums)):
    ax = plt.subplot(3, 3, i+1)
    # get label name
    plt.title(LABELS[y_train[nums[i]]])
    # get image
    plt.imshow((x_train[nums[i]]))
    plt.axis('off')


# Confusion matrix function testing
def produce_confusion_matrix(y_test, prediction, classes, labels, normalize=False):
    cm = confusion_matrix(y_true=y_test, y_pred=prediction)
    rows = cm.shape[0]
    cols = cm.shape[1]

    cmap=plt.cm.Greys
    title='Confusion Matrix'
    if normalize:
        cm = cm.astype('float')/cm.sum(axis=1)[:, np.tf.newaxis]
        print('Normalized confusion matrix')
    else:
        print('Confusion matrix without normalisation')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=17)
    plt.colorbar()
    tick_marks = np.arange(classes)
    plt.xticks(tick_marks, labels, rotation=45, fontsize=14)
    plt.yticks(tick_marks, labels, fontsize=14)

    fmt = '.2f' if normalize else 'd'

    for i, j in itertools.product(range(rows), range(cols)):
        plt.text(j, i, format(cm[i, j], fmt),
                horizontalalignment='center',
                color='white' if (cm[i,j] > cm.max() / 2.) else 'black')
    plt.tight_layout()
    plt.ylabel('Actual Label', fontsize=15)
    plt.xlabel('Predicted Label', fontsize=15)
    return cm


# Precision
def get_precision(cm):
  true_pos = np.diag(cm)
  score = true_pos / np.sum(cm, axis=0) # true pos + false pos
  print(f'Precision score = {score}')
  return score

# Recall
def get_recall(cm):
  true_pos = np.diag(cm)
  score = true_pos / np.sum(cm, axis=1) # true pos + false neg
  print(f'Recall score = {score}')
  return score


# F1-score
def get_f_1_score(cm, y_true, y_hat):
    """
    this computes unweighted F1 scores: by class and averaged unweighted
    also prints out precision and recall scores for each class
    """
    recall = get_recall(cm)
    precision = get_precision(cm)

    avg_recall = np.mean(recall)
    avg_prec = np.mean(precision)

    f1 = 2 * ((avg_recall * avg_prec) / (avg_recall + avg_prec))
    print(f'Unweighted F1 Score: {f1}')
    print(f'F1 score for each class :{f1_score(y_true, y_hat, average=None)}')

    weighted_f1 = f1_score(y_true, y_hat, average='weighted')
    print(f'Weighted overall F1: {weighted_f1}')


# MCC
def get_mcc(y, y_hat):
  mcc = matthews_corrcoef(y, y_hat)
  print(f'MCC is {mcc}')


def show_mis_predicted_img(prediction, labels, x=x_test, y=y_test):
   missed_id = np.where(p != y)[0]
   i = np.random.choice(missed_id)
  #  plt.imshow(x[i].reshape(px, px)) # necesaary for the grayscale img
   plt.title(f'True Label: {labels[y_test[i]]},\n Predicted: {labels[prediction[i]]}',
             fontsize=15);
   plt.imshow(x[i], cmap='gray')
   plt.axis('off')

def show_image(data):
    if data is not None:
        plt.imshow(data)
        plt.axis('off')
    else:
        print('No image to show')


def generate_performance_graph(value_1, value_2,
                               label_1, label_2,
                               title,
                               c1='navy', c2='lightseagreen'):
  plt.figure(figsize=(9,5))
  plt.title(MODEL+title, fontsize=16)
  plt.xlabel('Number of epochs', fontsize=14)
  plt.ylabel(title, fontsize=14)
  plt.plot(value_1, label=label_1, c=c1, linewidth=3, alpha=0.8)
  plt.plot(value_2, label=label_2, c=c2, linewidth=3, alpha=0.8)
  plt.legend(prop={'size':14})

# %%
 # Random samples must show the same images across models using the augmented datasets
sample_random_images(nums=[np.random.randint(1, TRAIN) for x in range(6)])

# %% [markdown]
# # Model CNN-LSTM

# %%
# Finalised model DO NOT CHANGE
# Common Convolution layer : ** DO NOT CHANGE ***
i = tf.keras.layers.Input(shape=x_train[0].shape)
x = tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3),strides=2, activation='relu', kernel_initializer='he_normal', padding='same')(i)
x = tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3),strides=2, activation='relu', kernel_initializer='he_normal', padding='same')(x)
#
x = tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3),strides=1, activation='relu', kernel_initializer='he_normal', padding='same')(x)
x = tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3),strides=1, activation='relu', kernel_initializer='he_normal', padding='same')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
#
x = tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3),strides=1, activation='relu', kernel_initializer='he_normal', padding='same')(x)
x = tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3),strides=1, activation='relu', kernel_initializer='he_normal', padding='same')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)

x = tf.keras.layers.Conv2D(filters=64, kernel_size=(2,2),strides=1, activation='relu', kernel_initializer='he_normal', padding='same')(x)
x = tf.keras.layers.Conv2D(filters=64, kernel_size=(2,2),strides=1, activation='relu', kernel_initializer='he_normal', padding='same')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
# End of the convolution layers

# LSTM
x = tf.keras.layers.Reshape((-1, 64))(x)
x = tf.keras.layers.LSTM(units=64, return_sequences=True)(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.LSTM(units=16)(x)
x = tf.keras.layers.Dropout(0.4)(x)
x = tf.keras.layers.Dense(CLASSES, activation='softmax')(x)

model = tf.keras.models.Model(i, x)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 300, 300, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 150, 150, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 75, 75, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 75, 75, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 75, 75, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 38, 38, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 38, 38, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 38, 38, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 19, 19, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 19, 19, 64)          │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 19, 19, 64)          │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 100, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 100, 64)             │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 100, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 16)                  │           5,184 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 3)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 155,219 (606.32 KB)
#  Trainable params: 155,219 (606.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Common settings for all models: DO NOT CHANGE
# Compile and fit
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE[1]),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
c = model.fit(x_train, y_train,
              batch_size=BATCH[1],
              validation_data=(x_val, y_val),
              shuffle=False,
              epochs=40)
# Out:
# Epoch 1/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 12s 75ms/step - accuracy: 0.3400 - loss: 1.0992 - val_accuracy: 0.5026 - val_loss: 1.0287
# Epoch 2/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.4764 - loss: 1.0244 - val_accuracy: 0.5077 - val_loss: 0.9439
# Epoch 3/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.4991 - loss: 0.9736 - val_accuracy: 0.5231 - val_loss: 0.8984
# Epoch 4/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.5506 - loss: 0.9061 - val_accuracy: 0.6308 - val_loss: 0.8157
# Epoch 5/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.5676 - loss: 0.8662 - val_accuracy: 0.5744 - val_loss: 0.8082
# Epoch 6/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.5681 - loss: 0.8777 - val_accuracy: 0.6000 - val_loss: 0.7800
# Epoch 7/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.6101 - loss: 0.8171 - val_accuracy: 0.6256 - val_loss: 0.7141
# Epoch 8/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.6226 - loss: 0.7659 - val_accuracy: 0.6615 - val_loss: 0.7573
# Epoch 9/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.6119 - loss: 0.8022 - val_accuracy: 0.6513 - val_loss: 0.6895
# Epoch 10/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.7047 - loss: 0.6495 - val_accuracy: 0.7128 - val_loss: 0.5993
# Epoch 11/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.7734 - loss: 0.5306 - val_accuracy: 0.8154 - val_loss: 0.4389
# Epoch 12/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.8249 - loss: 0.4649 - val_accuracy: 0.8256 - val_loss: 0.4357
# Epoch 13/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.8420 - loss: 0.4486 - val_accuracy: 0.8205 - val_loss: 0.4612
# Epoch 14/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.8730 - loss: 0.3570 - val_accuracy: 0.8667 - val_loss: 0.3809
# Epoch 15/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.8470 - loss: 0.4228 - val_accuracy: 0.8308 - val_loss: 0.4803
# Epoch 16/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.8294 - loss: 0.4751 - val_accuracy: 0.8872 - val_loss: 0.3355
# Epoch 17/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.8947 - loss: 0.3259 - val_accuracy: 0.8923 - val_loss: 0.3314
# Epoch 18/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.8138 - loss: 0.4753 - val_accuracy: 0.8000 - val_loss: 0.5603
# Epoch 19/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.8491 - loss: 0.4589 - val_accuracy: 0.8872 - val_loss: 0.3612
# Epoch 20/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.8974 - loss: 0.3157 - val_accuracy: 0.8872 - val_loss: 0.2991
# Epoch 21/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9162 - loss: 0.2646 - val_accuracy: 0.8923 - val_loss: 0.3007
# Epoch 22/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9199 - loss: 0.2422 - val_accuracy: 0.9179 - val_loss: 0.2702
# Epoch 23/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9274 - loss: 0.2429 - val_accuracy: 0.9077 - val_loss: 0.2513
# Epoch 24/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9405 - loss: 0.1921 - val_accuracy: 0.8872 - val_loss: 0.3427
# Epoch 25/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.9382 - loss: 0.1982 - val_accuracy: 0.8974 - val_loss: 0.2526
# Epoch 26/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9266 - loss: 0.2071 - val_accuracy: 0.8821 - val_loss: 0.3505
# Epoch 27/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9561 - loss: 0.1524 - val_accuracy: 0.9128 - val_loss: 0.2595
# Epoch 28/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9484 - loss: 0.1611 - val_accuracy: 0.8359 - val_loss: 0.5735
# Epoch 29/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.8405 - loss: 0.4351 - val_accuracy: 0.8923 - val_loss: 0.2876
# Epoch 30/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9535 - loss: 0.1582 - val_accuracy: 0.8974 - val_loss: 0.2976
# Epoch 31/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9552 - loss: 0.1432 - val_accuracy: 0.8974 - val_loss: 0.3234
# Epoch 32/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9130 - loss: 0.2478 - val_accuracy: 0.8872 - val_loss: 0.3182
# Epoch 33/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9335 - loss: 0.2025 - val_accuracy: 0.9179 - val_loss: 0.2345
# Epoch 34/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9583 - loss: 0.1300 - val_accuracy: 0.9128 - val_loss: 0.3137
# Epoch 35/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9661 - loss: 0.1109 - val_accuracy: 0.9128 - val_loss: 0.3502
# Epoch 36/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9513 - loss: 0.1689 - val_accuracy: 0.9179 - val_loss: 0.2559
# Epoch 37/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9659 - loss: 0.1134 - val_accuracy: 0.8923 - val_loss: 0.4532
# Epoch 38/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9481 - loss: 0.1710 - val_accuracy: 0.9179 - val_loss: 0.3194
# Epoch 39/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9766 - loss: 0.0925 - val_accuracy: 0.8359 - val_loss: 0.6031
# Epoch 40/40
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9337 - loss: 0.1989 - val_accuracy: 0.9179 - val_loss: 0.2574

# %% [markdown]
# ### Visualise training loss and accuracy

# %%
# Visualise loss
generate_performance_graph(value_1=c.history['loss'],
                           value_2=c.history['val_loss'],
                           label_1='Train loss',
                           label_2='Validation loss',
                           title='Loss')

# %%
# Visualise accuracy
generate_performance_graph(value_1=c.history['accuracy'],
                           value_2=c.history['val_accuracy'],
                           label_1='Train accuracy',
                           label_2='Validation accuracy',
                           title='Accuracy')

# %% [markdown]
# # Evaluation for test data
# ### 1. Loss and accuracy

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)
print(f'Test loss {test_loss:.3f}, Test accuracy: {test_accuracy:.2%}')
# Out:
# 7/7 - 0s - 35ms/step - accuracy: 0.9436 - loss: 0.1769
# Test loss 0.177, Test accuracy: 94.36%

# %% [markdown]
# ### 2. Confusion Matrix

# %%
p = np.argmax(model.predict(x_test), axis=1)
#print(f'actual label = {LABELS[y_test[0]]}, predicted = {LABELS[p[0]]}')
#print('Verify accuracy= ', sum(p==y_test)/len(y_test))
cmatrix = produce_confusion_matrix(y_test, p, CLASSES, labels=LABELS)
cmatrix
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Confusion matrix without normalisation
# array([[62,  6,  0],
#        [ 0, 58,  4],
#        [ 0,  1, 64]])

# %% [markdown]
# ### 3. F1-Score

# %%
get_f_1_score(cmatrix, y_true=y_test, y_hat=p)
# Out:
# Recall score = [0.91176471 0.93548387 0.98461538]
# Precision score = [1.         0.89230769 0.94117647]
# Unweighted F1 Score: 0.9442246101681671
# F1 score for each class :[0.95384615 0.91338583 0.96240602]
# Weighted overall F1: 0.943835131788844

# %% [markdown]
# ### 4. Mathews correlation coefficients

# %%
get_mcc(y=y_test, y_hat=p)
# Out:
# MCC is 0.9163903363334912

# %% [markdown]
# ### Verify mispredicted sample

# %%
show_mis_predicted_img(prediction=p, labels=LABELS)

# %%
# save model : ONLY for the best one!
model.save('Bean-CNN-LSTM_Flip.keras')

# %% [markdown]
# Licence for programs:
# All programs and data written for this project use the Apache license,
# the details can be found here:
# http://www.apache.org/licenses/
#
#
# Raw image data:
# The ibean data  with the following details and uses the MIT Licence.
# @ONLINE {beansdata,
#     author="Makerere AI Lab",
#     title="Bean disease dataset",
#     month="January",
#     year="2020",
#     url="https://github.com/AI-Lab-Makerere/ibean/"
# }
