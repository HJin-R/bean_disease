# %% [markdown]
# ## This file for developing the standard CNN Bean leaf disease classifier
# by using original, augmented datasets

# %% [markdown]
# ### Check Environment

# %%
# !cat /proc/cpuinfo | grep "model name" | head -1

# %%
# !cat /etc/*release

# %%
# !nvidia-smi

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import random
#from glob import glob
import itertools
import os
import matplotlib.pyplot as plt
#from re import X
from google.colab import files, drive

from sklearn.metrics import matthews_corrcoef, confusion_matrix, f1_score

# %matplotlib inline

# %%
# TensorFlow version
print(tf.version.VERSION)
# Out:
# 2.17.0

# %% [markdown]
# #### Set random seeds

# %%
# Random seeds - identical to CNN-LSTM
random.seed(111)
np.random.seed(111)
tf.random.set_seed(111)

# %%
# Connect to gdrive to get data
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Constants

# %%
WIDTH = 300 # image width
HEIGHT = 300  #image height
CHANNELS = 3 # colour channels
SHAPE = (WIDTH, HEIGHT, CHANNELS)
IMAGE_SIZE = [WIDTH, HEIGHT]
TOTAL_INPUTS = WIDTH * HEIGHT * CHANNELS
LABELS = ['Angular Leaf Spot', 'Bean Rust','Healthy']

# total number of training samples
TRAIN = 905
AUG_SAMPLES = 2715

# Total samples of images
SAMPLES = 1295
CLASSES = 3
#  Parameter and Hyperparameter values
BATCH = [16, 32, 64]
LEARNING_RATE = [1e-4, 1e-3, 1e-2]
NEURONS = [CLASSES, 16, 32, 64, 128]

MODEL = 'Baseline CNN: '

# Original data file names
X_TRAIN = 'x_train_original.npy'  #905
X_VAL = 'x_val.npy'  # 195
X_TEST = 'x_test.npy'  #195
Y_TRAIN = 'y_train_original.npy'  #905
Y_VAL = 'y_val.npy'  #195
Y_TEST = 'y_test.npy'  #195

# Transformed data file names
X_TRAIN_ROTATE = 'x_train_rotate.npy'
Y_TRAIN_ROTATE = 'y_train_rotate.npy'
X_TRAIN_FLIP = 'x_train_flip.npy'
Y_TRAIN_FLIP = 'y_train_flip.npy'
X_TRAIN_CROP = 'x_train_crop.npy'
Y_TRAIN_CROP = 'y_train_crop.npy'
X_TRAIN_BRIGHT = 'x_train_bright.npy'
Y_TRAIN_BRIGHT = 'y_train_bright.npy'

# %% [markdown]
# # Load data
# from files
# #### Note: variables x_train and y_train are reused for all training sets, validation and test sets are the same for all training

# %%
# Original
x_train = np.load('/content/drive/MyDrive/Colab Notebooks/'+ X_TRAIN)
y_train = np.load('/content/drive/MyDrive/Colab Notebooks/'+ Y_TRAIN)

x_val = np.load('/content/drive/MyDrive/Colab Notebooks/'+ X_VAL)
y_val = np.load('/content/drive/MyDrive/Colab Notebooks/'+ Y_VAL)

x_test = np.load('/content/drive/MyDrive/Colab Notebooks/'+ X_TEST)
y_test = np.load('/content/drive/MyDrive/Colab Notebooks/'+ Y_TEST)

# %%
# Reshape feature array into 3-dim
x_train = np.reshape(x_train, (-1, HEIGHT, WIDTH, CHANNELS))
x_val = np.reshape(x_val, (-1, HEIGHT, WIDTH, CHANNELS))
x_test = np.reshape(x_test, (-1, HEIGHT, WIDTH, CHANNELS))

# %% [markdown]
# ### Normalise data

# %%
# scaling data by max-min
x_train = x_train/255.0
x_test = x_test/255.0
x_val = x_val/255.0

# %%
#  Check the dimension
print(f'x_train= {x_train.shape}, x_val = {x_val.shape}, x_test = {x_test.shape}')
# Out:
# x_train= (905, 300, 300, 3), x_val = (195, 300, 300, 3), x_test = (195, 300, 300, 3)

# %% [markdown]
# # Core Functions

# %%
# show sample images
def sample_random_images(nums):
  fig = plt.figure(figsize=(10, 10))
  for i in range(len(nums)):
    ax = plt.subplot(3, 3, i+1)
    # get label name
    plt.title(LABELS[y_train[nums[i]]])
    # get image
    plt.imshow((x_train[nums[i]]))
    plt.axis('off')


# Confusion matrix function testing
def produce_confusion_matrix(y_test, prediction, classes, labels, normalize=False):
    cm = confusion_matrix(y_true=y_test, y_pred=prediction)
    rows = cm.shape[0]
    cols = cm.shape[1]

    cmap=plt.cm.Greys
    title='Confusion Matrix'
    if normalize:
        cm = cm.astype('float')/cm.sum(axis=1)[:, np.tf.newaxis]
        print('Normalized confusion matrix')
    else:
        print('Confusion matrix without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(MODEL+title, fontsize=17)
    plt.colorbar()
    tick_marks = np.arange(classes)
    plt.xticks(tick_marks, labels, rotation=45, fontsize=14)
    plt.yticks(tick_marks, labels, fontsize=14)

    fmt = '.2f' if normalize else 'd'

    for i, j in itertools.product(range(rows), range(cols)):
        plt.text(j, i, format(cm[i, j], fmt),
                horizontalalignment='center',
                color='white' if (cm[i,j] > cm.max() / 2.) else 'black')
    plt.tight_layout()
    plt.ylabel('Actual Label', fontsize=15)
    plt.xlabel('Predicted Label', fontsize=15)
    return cm


# Precision
def get_precision(cm):
  true_pos = np.diag(cm)
  score = true_pos / np.sum(cm, axis=0) # true pos + true neg
  print(f'Precision score = {score}')
  return score

# Recall
def get_recall(cm):
  true_pos = np.diag(cm)
  score = true_pos / np.sum(cm, axis=1) # true pos + false neg
  print(f'Recall score = {score}')
  return score


# F1-score
def get_f_1_score(cm, y_true, y_hat):
    """
    this computes unweighted F1 scores: by class and averaged unweighted
    also prints out precision and recall scores for each class
    """
    recall = get_recall(cm)
    precision = get_precision(cm)

    avg_recall = np.mean(recall)
    avg_prec = np.mean(precision)

    f1 = 2 * ((avg_recall * avg_prec) / (avg_recall + avg_prec))
    print(f'Unweighted F1 Score: {f1}')
    print(f'F1 score for each class :{f1_score(y_true, y_hat, average=None)}')

    weighted_f1 = f1_score(y_true, y_hat, average='weighted')
    print(f'Weighted overall F1: {weighted_f1}')


# MCC
def get_mcc(y, y_hat):
  mcc = matthews_corrcoef(y, y_hat)
  print(f'MCC is {mcc}')


def show_mis_predicted_img(prediction, labels, x=x_test, y=y_test):
   missed_id = np.where(p != y)[0]
   i = np.random.choice(missed_id)
  #  plt.imshow(x[i].reshape(px, px)) # necesaary for the grayscale img
   plt.title(f'True Label: {labels[y_test[i]]},\n Predicted: {labels[prediction[i]]}',
             fontsize=15);
   plt.imshow(x[i], cmap='gray')
   plt.axis('off')


def show_image(data):
    if data is not None:
        plt.imshow(data)
        plt.axis('off')
    else:
        print('No image to show')


def generate_performance_graph(value_1, value_2,
                               label_1, label_2,
                               title,
                               c1='navy', c2='lightseagreen'):
  plt.figure(figsize=(9,5))
  plt.title(MODEL+title, fontsize=16)
  plt.xlabel('Number of epochs', fontsize=14)
  plt.ylabel(title, fontsize=14)
  plt.plot(value_1, label=label_1, c=c1, linewidth=3, alpha=0.8)
  plt.plot(value_2, label=label_2, c=c2, linewidth=3, alpha=0.8)
  plt.legend(prop={'size':14})

# %%
# Check random images - use the same list for augmentation - choices should be the same as other models
sample_random_images(nums=[np.random.randint(1, TRAIN) for x in range(6)])

# %% [markdown]
# # Model Standard CNN
# Model is built with funtional API

# %%
# Current best config
# Common Convolution layer : ** DO NOT CHANGE ***
i = tf.keras.layers.Input(shape=x_train[0].shape)
x = tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3),strides=2, activation='relu', kernel_initializer='he_normal', padding='same')(i)
x = tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3),strides=2, activation='relu', kernel_initializer='he_normal', padding='same')(x)
#
x = tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3),strides=1, activation='relu', kernel_initializer='he_normal', padding='same')(x)
x = tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3),strides=1, activation='relu', kernel_initializer='he_normal', padding='same')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
#
x = tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3),strides=1, activation='relu', kernel_initializer='he_normal', padding='same')(x)
x = tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3),strides=1, activation='relu', kernel_initializer='he_normal', padding='same')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
#
x = tf.keras.layers.Conv2D(filters=64, kernel_size=(2,2),strides=1, activation='relu', kernel_initializer='he_normal', padding='same')(x)
x = tf.keras.layers.Conv2D(filters=64, kernel_size=(2,2),strides=1, activation='relu', kernel_initializer='he_normal', padding='same')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
# End of the convolution layers

# Feed forward neural networks
x = tf.keras.layers.Flatten()(x)  # flatten the array for NN
x = tf.keras.layers.Dense(units=64, activation='relu', kernel_initializer= tf.keras.initializers.HeNormal)(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(units=8, activation='relu', kernel_initializer= tf.keras.initializers.HeNormal)(x)
x = tf.keras.layers.Dropout(0.3)(x)
x = tf.keras.layers.Dense(units=CLASSES, activation='softmax')(x)

model = tf.keras.models.Model(i, x)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 300, 300, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 150, 150, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 75, 75, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 75, 75, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 75, 75, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 38, 38, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 38, 38, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 38, 38, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 19, 19, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 19, 19, 64)          │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 19, 19, 64)          │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 6400)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │         409,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 3)                   │              27 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 527,171 (2.01 MB)
#  Trainable params: 527,171 (2.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# COMMON settings DO NOT CHANGE
# Compile and fit
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE[1]),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
c = model.fit(x_train, y_train,
              batch_size=BATCH[1],
              validation_data=(x_val, y_val),
              shuffle=False,
              epochs=40)
# Out:
# Epoch 1/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 283ms/step - accuracy: 0.3188 - loss: 1.1982 - val_accuracy: 0.3487 - val_loss: 1.0964
# Epoch 2/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.3422 - loss: 1.0984 - val_accuracy: 0.3436 - val_loss: 1.0986
# Epoch 3/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.3433 - loss: 1.0985 - val_accuracy: 0.3436 - val_loss: 1.0986
# Epoch 4/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.3422 - loss: 1.0985 - val_accuracy: 0.3538 - val_loss: 1.0984
# Epoch 5/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.3408 - loss: 1.0959 - val_accuracy: 0.4667 - val_loss: 1.0732
# Epoch 6/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.3834 - loss: 1.0874 - val_accuracy: 0.4513 - val_loss: 1.0429
# Epoch 7/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4241 - loss: 1.0555 - val_accuracy: 0.4051 - val_loss: 1.0316
# Epoch 8/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4524 - loss: 1.0155 - val_accuracy: 0.4718 - val_loss: 1.0535
# Epoch 9/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4485 - loss: 1.0285 - val_accuracy: 0.3795 - val_loss: 1.0756
# Epoch 10/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4464 - loss: 1.0186 - val_accuracy: 0.5744 - val_loss: 0.9086
# Epoch 11/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5517 - loss: 0.9541 - val_accuracy: 0.5641 - val_loss: 0.8849
# Epoch 12/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4736 - loss: 0.9493 - val_accuracy: 0.5897 - val_loss: 0.9318
# Epoch 13/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5618 - loss: 0.8860 - val_accuracy: 0.5487 - val_loss: 1.0236
# Epoch 14/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5777 - loss: 0.9180 - val_accuracy: 0.4821 - val_loss: 0.9837
# Epoch 15/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5272 - loss: 0.8897 - val_accuracy: 0.6513 - val_loss: 0.8267
# Epoch 16/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6233 - loss: 0.7977 - val_accuracy: 0.6051 - val_loss: 0.8076
# Epoch 17/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6377 - loss: 0.7694 - val_accuracy: 0.6410 - val_loss: 0.7771
# Epoch 18/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6036 - loss: 0.7525 - val_accuracy: 0.6462 - val_loss: 0.7874
# Epoch 19/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6171 - loss: 0.7081 - val_accuracy: 0.6821 - val_loss: 0.7374
# Epoch 20/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6516 - loss: 0.6692 - val_accuracy: 0.6718 - val_loss: 0.7356
# Epoch 21/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6814 - loss: 0.6609 - val_accuracy: 0.7128 - val_loss: 0.6977
# Epoch 22/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6865 - loss: 0.6345 - val_accuracy: 0.6667 - val_loss: 0.7798
# Epoch 23/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7193 - loss: 0.6202 - val_accuracy: 0.6923 - val_loss: 0.7331
# Epoch 24/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7050 - loss: 0.5525 - val_accuracy: 0.7846 - val_loss: 0.6473
# Epoch 25/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7329 - loss: 0.5303 - val_accuracy: 0.7487 - val_loss: 0.6798
# Epoch 26/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7232 - loss: 0.5476 - val_accuracy: 0.7487 - val_loss: 0.6575
# Epoch 27/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7326 - loss: 0.5189 - val_accuracy: 0.7282 - val_loss: 0.6694
# Epoch 28/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7218 - loss: 0.5673 - val_accuracy: 0.7179 - val_loss: 0.6850
# Epoch 29/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7305 - loss: 0.6007 - val_accuracy: 0.7744 - val_loss: 0.7089
# Epoch 30/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.7546 - loss: 0.4954 - val_accuracy: 0.7692 - val_loss: 0.5995
# Epoch 31/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7539 - loss: 0.4689 - val_accuracy: 0.7538 - val_loss: 0.6220
# Epoch 32/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7965 - loss: 0.4319 - val_accuracy: 0.7949 - val_loss: 0.6179
# Epoch 33/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8265 - loss: 0.3868 - val_accuracy: 0.7692 - val_loss: 0.7653
# Epoch 34/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8309 - loss: 0.3775 - val_accuracy: 0.8308 - val_loss: 0.5600
# Epoch 35/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8280 - loss: 0.3728 - val_accuracy: 0.8410 - val_loss: 0.4588
# Epoch 36/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8570 - loss: 0.3387 - val_accuracy: 0.8051 - val_loss: 0.7221
# Epoch 37/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8232 - loss: 0.3673 - val_accuracy: 0.8205 - val_loss: 0.5826
# Epoch 38/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8388 - loss: 0.3547 - val_accuracy: 0.8000 - val_loss: 0.6345
# Epoch 39/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8705 - loss: 0.3252 - val_accuracy: 0.8359 - val_loss: 0.7763
# Epoch 40/40
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8503 - loss: 0.3397 - val_accuracy: 0.8410 - val_loss: 0.5867

# %% [markdown]
# ### Visualise training/validation loss and accuracy

# %%
# Loss function
generate_performance_graph(value_1=c.history['loss'],
                           value_2=c.history['val_loss'],
                           label_1='Train loss',
                           label_2='Validation loss',
                           title='Loss')

# %%
# Accuracy
generate_performance_graph(value_1=c.history['accuracy'],
                           value_2=c.history['val_accuracy'],
                           label_1='Train accuracy',
                           label_2='Validation accuracy',
                           title='Accuracy')

# %% [markdown]
# # Evaluation for test data
# ### 1. Loss and accuracy

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)
print(f'Test loss: {test_loss:.3f}, Test accuracy: {test_accuracy:.3%}')
# Out:
# 7/7 - 0s - 24ms/step - accuracy: 0.8410 - loss: 0.5180
# Test loss: 0.518, Test accuracy: 84.103%

# %% [markdown]
# ### 2. Confusion Matrix

# %%
p = np.argmax(model.predict(x_test), axis=1)
#print('Verify accuracy= ', sum(p==y_test)/len(y_test))
cmatrix = produce_confusion_matrix(y_test, p, CLASSES, labels=LABELS)
cmatrix
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# Confusion matrix without normalization
# array([[61,  6,  1],
#        [ 9, 47,  6],
#        [ 0,  9, 56]])

# %% [markdown]
# ### 3. F1-Score

# %%
get_f_1_score(cmatrix, y_true=y_test, y_hat=p)
# Out:
# Recall score = [0.89705882 0.75806452 0.86153846]
# Precision score = [0.87142857 0.75806452 0.88888889]
# Unweighted F1 Score: 0.8391738649936228
# F1 score for each class :[0.88405797 0.75806452 0.875     ]
# Weighted overall F1: 0.8409791898922333

# %% [markdown]
# ### 4. Mathews correlation coefficients

# %%
get_mcc(y=y_test, y_hat=p)
# Out:
# MCC is 0.7614328056038459

# %% [markdown]
# ### Verify mispredicted samples

# %%
show_mis_predicted_img(prediction=p,labels=LABELS)

# %%
# save the best performing model
model.save('Bean-CNN_Original.keras')
